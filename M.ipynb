# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from random import randint
import math as m

# %matplotlib inline

# %%
            

y = np.array([3, 8, 4, 8, 3])
z = np.array([1, 6, 2, 6, 1])
a = np.array([1])
b = np.array([0,1])



plt.plot(y,linestyle = 'dotted', c = 'b')
plt.plot(z,linestyle = 'dotted')
plt.plot(a, linestyle = 'dotted', c = 'b')
plt.show()
